# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
amherst=pd.read_csv('../amherstPRECIP.csv', header=0,
        index_col=['year','month','day'],names=['row','year','month','day','amherst','flag']).drop(['row','flag'],axis=1)
amherst.head()
# Out:
#                 amherst
# year month day
# 1893 1     2      215.0
#            3        0.0
#            4        0.0
#            5        0.0
#            6        4.0

# %%
bedford=pd.read_csv('../bedfordPRECIP.csv', header=0,
        index_col=['year','month','day'],names=['row','year','month','day','bedford','flag']).drop(['row','flag'],axis=1)

bedford.head()
# Out:
#                 bedford
# year month day
# 1957 5     2        NaN
#            3        NaN
#            4        NaN
#            5        NaN
#            6        0.0

# %%
bluehill=pd.read_csv('../bluehillPRECIP.csv', header=0,
        index_col=['year','month','day'],names=['row','year','month','day','bluehill','flag']).drop(['row','flag'],axis=1)

# %%
gb=pd.read_csv('../gbPRECIP.csv', header=0,
        index_col=['year','month','day'],names=['row','year','month','day','gb','flag']).drop(['row','flag'],axis=1)

# %%
lawrence=pd.read_csv('../lawrencePRECIP.csv', header=0,
        index_col=['year','month','day'],names=['row','year','month','day','lawrence','flag']).drop(['row','flag'],axis=1)

# %%
nb=pd.read_csv('../nbPRECIP.csv', header=0,
        index_col=['year','month','day'],names=['row','year','month','day','nb','flag']).drop(['row','flag'],axis=1)

# %%
pk=pd.read_csv('../pkPRECIP.csv', header=0,
        index_col=['year','month','day'],names=['row','year','month','day','pk','flag']).drop(['row','flag'],axis=1)

# %%
ptown=pd.read_csv('../ptownPRECIP.csv', header=0,
        index_col=['year','month','day'],names=['row','year','month','day','ptown','flag']).drop(['row','flag'],axis=1)

# %%
reading=pd.read_csv('../readingPRECIP.csv', header=0,
        index_col=['year','month','day'],names=['row','year','month','day','reading','flag']).drop(['row','flag'],axis=1)

# %%
taunton=pd.read_csv('../tauntonPRECIP.csv', header=0,
        index_col=['year','month','day'],names=['row','year','month','day','taunton','flag']).drop(['row','flag'],axis=1)

# %%
walpole=pd.read_csv('../walpolePRECIP.csv', header=0,
        index_col=['year','month','day'],names=['row','year','month','day','walpole','flag']).drop(['row','flag'],axis=1)

# %%
wm=pd.read_csv('../wmPRECIP.csv', header=0,
        index_col=['year','month','day'],names=['row','year','month','day','wm','flag']).drop(['row','flag'],axis=1)

# %%
rain = amherst.join([bedford,bluehill,gb,lawrence,nb,pk,ptown,reading,taunton,walpole,wm],how='outer')

# %%
rain
# Out:
#                 amherst  bedford  bluehill  gb  lawrence    nb     pk  ptown  \
# year month day
# 0    0     0        0.0      NaN       NaN NaN       NaN   NaN    NaN    NaN
# 1893 1     2      215.0      NaN      22.0 NaN      76.0   NaN  117.0    NaN
#            3        0.0      NaN      73.0 NaN       0.0  40.0    0.0    NaN
#            4        0.0      NaN       0.0 NaN       0.0   NaN    0.0    NaN
#            5        0.0      NaN       0.0 NaN       0.0   NaN    0.0    NaN
#            6        4.0      NaN       0.0 NaN      31.0   NaN   45.0    NaN
#            7        0.0      NaN       0.0 NaN       0.0   NaN    0.0    NaN
#            8        0.0      NaN       0.0 NaN       0.0   6.0    0.0    NaN
#            9        NaN      NaN       0.0 NaN       0.0   NaN    0.0    NaN
#            10       6.0      NaN       0.0 NaN      42.0   NaN   38.0    NaN
#            11       NaN      NaN       0.0 NaN       0.0   NaN    0.0    NaN
# ...

# %% [markdown]
# Remove the one record for year, month, day = zero

# %%
rain.drop([0,0,0])
# Out:
#                 amherst  bedford  bluehill  gb  lawrence    nb     pk  ptown  \
# year month day
# 1893 1     2      215.0      NaN      22.0 NaN      76.0   NaN  117.0    NaN
#            3        0.0      NaN      73.0 NaN       0.0  40.0    0.0    NaN
#            4        0.0      NaN       0.0 NaN       0.0   NaN    0.0    NaN
#            5        0.0      NaN       0.0 NaN       0.0   NaN    0.0    NaN
#            6        4.0      NaN       0.0 NaN      31.0   NaN   45.0    NaN
#            7        0.0      NaN       0.0 NaN       0.0   NaN    0.0    NaN
#            8        0.0      NaN       0.0 NaN       0.0   6.0    0.0    NaN
#            9        NaN      NaN       0.0 NaN       0.0   NaN    0.0    NaN
#            10       6.0      NaN       0.0 NaN      42.0   NaN   38.0    NaN
#            11       NaN      NaN       0.0 NaN       0.0   NaN    0.0    NaN
#            12       0.0      NaN       0.0 NaN       0.0   5.0    0.0    NaN
# ...

# %%
rain.shape
# Out:
# (44529, 15)

# %%
rain.describe()
# Out:
#                year         month           day       amherst       bedford  \
# count  44529.000000  44529.000000  44529.000000  42803.000000  18839.000000
# mean    1953.501359      6.526151     15.720879     11.777936     12.654175
# std       35.216807      3.447829      8.796168     31.666431     34.113732
# min     1893.000000      1.000000      1.000000      0.000000      0.000000
# 25%     1923.000000      4.000000      8.000000      0.000000      0.000000
# 50%     1954.000000      7.000000     16.000000      0.000000      0.000000
# 75%     1984.000000     10.000000     23.000000      6.000000      6.000000
# max     2014.000000     12.000000     31.000000    756.000000    783.000000
#
#            bluehill            gb      lawrence            nb            pk  \
# count  43998.000000  10904.000000  41848.000000  34297.000000  42817.000000
# mean      13.338447     12.238903     10.875812     12.472053     13.047668
# ...

# %%
rain
# Out:
#        year  month  day  amherst  bedford  bluehill  gb  lawrence    nb  \
# 0      1893      1    2    215.0      NaN      22.0 NaN      76.0   NaN
# 1      1893      1    3      0.0      NaN      73.0 NaN       0.0  40.0
# 2      1893      1    4      0.0      NaN       0.0 NaN       0.0   NaN
# 3      1893      1    5      0.0      NaN       0.0 NaN       0.0   NaN
# 4      1893      1    6      4.0      NaN       0.0 NaN      31.0   NaN
# 5      1893      1    7      0.0      NaN       0.0 NaN       0.0   NaN
# 6      1893      1    8      0.0      NaN       0.0 NaN       0.0   6.0
# 7      1893      1    9      NaN      NaN       0.0 NaN       0.0   NaN
# 8      1893      1   10      6.0      NaN       0.0 NaN      42.0   NaN
# 9      1893      1   11      NaN      NaN       0.0 NaN       0.0   NaN
# 10     1893      1   12      0.0      NaN       0.0 NaN       0.0   5.0
# 11     1893      1   13      NaN      NaN       0.0 NaN       0.0   NaN
# ...
