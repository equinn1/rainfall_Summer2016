# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
rain=pd.read_csv('../amherstPRECIP.csv', header=0,
        index_col=['year','month','day'],names=['row','year','month','day','amherst','flag']).drop(['row','flag'],axis=1)
rain.head()
# Out:
#                 amherst
# year month day
# 1893 1     2      215.0
#            3        0.0
#            4        0.0
#            5        0.0
#            6        4.0

# %%
bedford=pd.read_csv('../bedfordPRECIP.csv', header=0,
        index_col=['year','month','day'],names=['row','year','month','day','bedford','flag']).drop(['row','flag'],axis=1)

rain = rain.merge(bedford, how='outer',left_on=['year','month','day'], right_on=['year','month','day'])
rain.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-17f49e39c24a> in <module>()
#       2         index_col=['year','month','day'],names=['row','year','month','day','bedford','flag']).drop(['row','flag'],axis=1)
#       3
# ----> 4 rain = rain.merge(bedford, how='outer',left_on=['year','month','day'], right_on=['year','month','day'])
#       5 rain.head()
#
# /usr/lib64/python2.7/site-packages/pandas/core/frame.pyc in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator)
#    4616                      right_on=right_on, left_index=left_index,
#    4617                      right_index=right_index, sort=sort, suffixes=suffixes,
# -> 4618                      copy=copy, indicator=indicator)
#    4619
#    4620     def round(self, decimals=0, *args, **kwargs):
#
# ...

# %%
bluehill=pd.read_csv('../bluehillPRECIP.csv', header=0,
                    names=['row','year','month','day','bluehill','flag']).drop(['row','flag'],axis=1)

rain = rain.merge(bluehill, how='outer',left_on=['year','month','day'], right_on=['year','month','day'])
rain.head()
# Out:
#    year  month  day  amherst  bedford  bluehill
# 0  1893      1    2    215.0      NaN      22.0
# 1  1893      1    3      0.0      NaN      73.0
# 2  1893      1    4      0.0      NaN       0.0
# 3  1893      1    5      0.0      NaN       0.0
# 4  1893      1    6      4.0      NaN       0.0

# %%
gb=pd.read_csv('../gbPRECIP.csv', header=0,
                    names=['row','year','month','day','gb','flag']).drop(['row','flag'],axis=1)


rain = rain.merge(gb, how='outer',left_on=['year','month','day'], right_on=['year','month','day'])
rain.head()
# Out:
#    year  month  day  amherst  bedford  bluehill  gb
# 0  1893      1    2    215.0      NaN      22.0 NaN
# 1  1893      1    3      0.0      NaN      73.0 NaN
# 2  1893      1    4      0.0      NaN       0.0 NaN
# 3  1893      1    5      0.0      NaN       0.0 NaN
# 4  1893      1    6      4.0      NaN       0.0 NaN

# %%
lawrence=pd.read_csv('../lawrencePRECIP.csv', header=0,
                    names=['row','year','month','day','lawrence','flag']).drop(['row','flag'],axis=1)


rain = rain.merge(lawrence, how='outer',left_on=['year','month','day'], right_on=['year','month','day'])
rain.head()
# Out:
#    year  month  day  amherst  bedford  bluehill  gb  lawrence
# 0  1893      1    2    215.0      NaN      22.0 NaN      76.0
# 1  1893      1    3      0.0      NaN      73.0 NaN       0.0
# 2  1893      1    4      0.0      NaN       0.0 NaN       0.0
# 3  1893      1    5      0.0      NaN       0.0 NaN       0.0
# 4  1893      1    6      4.0      NaN       0.0 NaN      31.0

# %%
nb=pd.read_csv('../nbPRECIP.csv', header=0,
                    names=['row','year','month','day','nb','flag']).drop(['row','flag'],axis=1)


rain = rain.merge(nb, how='outer',left_on=['year','month','day'], right_on=['year','month','day'])
rain.head()
# Out:
#    year  month  day  amherst  bedford  bluehill  gb  lawrence    nb
# 0  1893      1    2    215.0      NaN      22.0 NaN      76.0   NaN
# 1  1893      1    3      0.0      NaN      73.0 NaN       0.0  40.0
# 2  1893      1    4      0.0      NaN       0.0 NaN       0.0   NaN
# 3  1893      1    5      0.0      NaN       0.0 NaN       0.0   NaN
# 4  1893      1    6      4.0      NaN       0.0 NaN      31.0   NaN

# %%
pk=pd.read_csv('../pkPRECIP.csv', header=0,
                    names=['row','year','month','day','pk','flag']).drop(['row','flag'],axis=1)


rain = rain.merge(pk, how='outer',left_on=['year','month','day'], right_on=['year','month','day'])
rain.head()
# Out:
#    year  month  day  amherst  bedford  bluehill  gb  lawrence    nb     pk
# 0  1893      1    2    215.0      NaN      22.0 NaN      76.0   NaN  117.0
# 1  1893      1    3      0.0      NaN      73.0 NaN       0.0  40.0    0.0
# 2  1893      1    4      0.0      NaN       0.0 NaN       0.0   NaN    0.0
# 3  1893      1    5      0.0      NaN       0.0 NaN       0.0   NaN    0.0
# 4  1893      1    6      4.0      NaN       0.0 NaN      31.0   NaN   45.0

# %%
ptown=pd.read_csv('../ptownPRECIP.csv', header=0,
                    names=['row','year','month','day','ptown','flag']).drop(['row','flag'],axis=1)


rain = rain.merge(ptown, how='outer',left_on=['year','month','day'], right_on=['year','month','day'])
rain.head()
# Out:
#    year  month  day  amherst  bedford  bluehill  gb  lawrence    nb     pk  \
# 0  1893      1    2    215.0      NaN      22.0 NaN      76.0   NaN  117.0
# 1  1893      1    3      0.0      NaN      73.0 NaN       0.0  40.0    0.0
# 2  1893      1    4      0.0      NaN       0.0 NaN       0.0   NaN    0.0
# 3  1893      1    5      0.0      NaN       0.0 NaN       0.0   NaN    0.0
# 4  1893      1    6      4.0      NaN       0.0 NaN      31.0   NaN   45.0
#
#    ptown
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN

# %%
reading=pd.read_csv('../readingPRECIP.csv', header=0,
                    names=['row','year','month','day','reading','flag']).drop(['row','flag'],axis=1)


rain = rain.merge(reading, how='outer',left_on=['year','month','day'], right_on=['year','month','day'])
rain.head()
# Out:
#    year  month  day  amherst  bedford  bluehill  gb  lawrence    nb     pk  \
# 0  1893      1    2    215.0      NaN      22.0 NaN      76.0   NaN  117.0
# 1  1893      1    3      0.0      NaN      73.0 NaN       0.0  40.0    0.0
# 2  1893      1    4      0.0      NaN       0.0 NaN       0.0   NaN    0.0
# 3  1893      1    5      0.0      NaN       0.0 NaN       0.0   NaN    0.0
# 4  1893      1    6      4.0      NaN       0.0 NaN      31.0   NaN   45.0
#
#    ptown  reading
# 0    NaN      NaN
# 1    NaN      NaN
# 2    NaN      NaN
# 3    NaN      NaN
# 4    NaN      NaN

# %%
taunton=pd.read_csv('../tauntonPRECIP.csv', header=0,
                    names=['row','year','month','day','taunton','flag']).drop(['row','flag'],axis=1)


rain = rain.merge(taunton, how='outer',left_on=['year','month','day'], right_on=['year','month','day'])
rain.head()
# Out:
#    year  month  day  amherst  bedford  bluehill  gb  lawrence    nb     pk  \
# 0  1893      1    2    215.0      NaN      22.0 NaN      76.0   NaN  117.0
# 1  1893      1    3      0.0      NaN      73.0 NaN       0.0  40.0    0.0
# 2  1893      1    4      0.0      NaN       0.0 NaN       0.0   NaN    0.0
# 3  1893      1    5      0.0      NaN       0.0 NaN       0.0   NaN    0.0
# 4  1893      1    6      4.0      NaN       0.0 NaN      31.0   NaN   45.0
#
#    ptown  reading  taunton
# 0    NaN      NaN    123.0
# 1    NaN      NaN      0.0
# 2    NaN      NaN      0.0
# 3    NaN      NaN      0.0
# 4    NaN      NaN    143.0

# %%
walpole=pd.read_csv('../walpolePRECIP.csv', header=0,
                    names=['row','year','month','day','walpole','flag']).drop(['row','flag'],axis=1)


rain = rain.merge(walpole, how='outer',left_on=['year','month','day'], right_on=['year','month','day'])
rain.head()
# Out:
#    year  month  day  amherst  bedford  bluehill  gb  lawrence    nb     pk  \
# 0  1893      1    2    215.0      NaN      22.0 NaN      76.0   NaN  117.0
# 1  1893      1    3      0.0      NaN      73.0 NaN       0.0  40.0    0.0
# 2  1893      1    4      0.0      NaN       0.0 NaN       0.0   NaN    0.0
# 3  1893      1    5      0.0      NaN       0.0 NaN       0.0   NaN    0.0
# 4  1893      1    6      4.0      NaN       0.0 NaN      31.0   NaN   45.0
#
#    ptown  reading  taunton  walpole
# 0    NaN      NaN    123.0      NaN
# 1    NaN      NaN      0.0      NaN
# 2    NaN      NaN      0.0      NaN
# 3    NaN      NaN      0.0      NaN
# 4    NaN      NaN    143.0      NaN

# %%
wm=pd.read_csv('../wmPRECIP.csv', header=0,
                    names=['row','year','month','day','wm','flag']).drop(['row','flag'],axis=1)


rain = rain.merge(wm, how='outer',left_on=['year','month','day'], right_on=['year','month','day'])
rain.head()
# Out:
#    year  month  day  amherst  bedford  bluehill  gb  lawrence    nb     pk  \
# 0  1893      1    2    215.0      NaN      22.0 NaN      76.0   NaN  117.0
# 1  1893      1    3      0.0      NaN      73.0 NaN       0.0  40.0    0.0
# 2  1893      1    4      0.0      NaN       0.0 NaN       0.0   NaN    0.0
# 3  1893      1    5      0.0      NaN       0.0 NaN       0.0   NaN    0.0
# 4  1893      1    6      4.0      NaN       0.0 NaN      31.0   NaN   45.0
#
#    ptown  reading  taunton  walpole  wm
# 0    NaN      NaN    123.0      NaN NaN
# 1    NaN      NaN      0.0      NaN NaN
# 2    NaN      NaN      0.0      NaN NaN
# 3    NaN      NaN      0.0      NaN NaN
# 4    NaN      NaN    143.0      NaN NaN

# %%
rain.shape
# Out:
# (44530, 15)

# %% [markdown]
# Remove the one record for year zero

# %%
rain = rain.loc[rain.year!=0]

# %%
rain.shape
# Out:
# (44529, 15)

# %%
rain.describe()
# Out:
#                year         month           day       amherst       bedford  \
# count  44529.000000  44529.000000  44529.000000  42803.000000  18839.000000
# mean    1953.501359      6.526151     15.720879     11.777936     12.654175
# std       35.216807      3.447829      8.796168     31.666431     34.113732
# min     1893.000000      1.000000      1.000000      0.000000      0.000000
# 25%     1923.000000      4.000000      8.000000      0.000000      0.000000
# 50%     1954.000000      7.000000     16.000000      0.000000      0.000000
# 75%     1984.000000     10.000000     23.000000      6.000000      6.000000
# max     2014.000000     12.000000     31.000000    756.000000    783.000000
#
#            bluehill            gb      lawrence            nb            pk  \
# count  43998.000000  10904.000000  41848.000000  34297.000000  42817.000000
# mean      13.338447     12.238903     10.875812     12.472053     13.047668
# ...

# %%
rain
# Out:
#        year  month  day  amherst  bedford  bluehill  gb  lawrence    nb  \
# 0      1893      1    2    215.0      NaN      22.0 NaN      76.0   NaN
# 1      1893      1    3      0.0      NaN      73.0 NaN       0.0  40.0
# 2      1893      1    4      0.0      NaN       0.0 NaN       0.0   NaN
# 3      1893      1    5      0.0      NaN       0.0 NaN       0.0   NaN
# 4      1893      1    6      4.0      NaN       0.0 NaN      31.0   NaN
# 5      1893      1    7      0.0      NaN       0.0 NaN       0.0   NaN
# 6      1893      1    8      0.0      NaN       0.0 NaN       0.0   6.0
# 7      1893      1    9      NaN      NaN       0.0 NaN       0.0   NaN
# 8      1893      1   10      6.0      NaN       0.0 NaN      42.0   NaN
# 9      1893      1   11      NaN      NaN       0.0 NaN       0.0   NaN
# 10     1893      1   12      0.0      NaN       0.0 NaN       0.0   5.0
# 11     1893      1   13      NaN      NaN       0.0 NaN       0.0   NaN
# ...
